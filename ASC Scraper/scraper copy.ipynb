# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.by import By 
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service

# %%
service = Service("/usr/bin/chromedriver")  # Update path if different
driver = webdriver.Chrome(service=service)
dD=webdriver.Chrome(service=service)
driver.get("https://www.imdb.com/chart/top/") 
info=driver.find_element(By.XPATH,f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/div[1]/div/div/button[1]")
info.click()

# %%
Movies=pd.DataFrame(0,index=range(1,101),columns=['Movie Title','Image','Release Date','Duration Length','film Rating','Rating','Country of Origin','Directors','Stars','Summary or Plot'])
drivers=[]
# Drivers=[webdriver.Chrome(service=service)]*100
# link=[None]*100

# %%
# for i in range(99,-1):
#         Drivers[i].get("https://www.imdb.com/chart/top/")
#         info=driver.find_element(By.XPATH,f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/div[1]/div/div/button[1]")
#         info.click()

# %%
for i in range(1,6):
        info=driver.find_element(By.XPATH,f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[2]/div[1]/a")
        dD.get(info.get_attribute('href'))
        drivers.append(dD)
        Directors=""
        k=7
        j=2
        while True:
                Director= driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[2]/span/span[{j}]/a")
                Directors=Directors+Director.text+", "
                try:
                        Director=driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[2]/span/span[{j+1}]/a")
                        j=j+1
                except:
                        Movies.iloc[(i-1),k]=Directors[:-2]
                        if k==7 :
                                k=8
                        else:
                                break
                        j=j+2
                        Directors=""
        
        title=driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[2]/div[1]/a/h3")
        Movies.iloc[(i-1),0]=title.text

        image=driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[1]/div/div[2]/img")
        Movies.iloc[(i-1),1]=image.get_attribute('src')

        for j in range(2,4):
                try:
                        elem= driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[2]/div[2]/span[{j}]")
                        Movies.iloc[(i-1),(j+1)]=elem.text
                except:
                        continue

        Rating=driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[2]/span/div/span/span[1]")
        number=driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[1]/div[2]/span/div/span/span[2]")
        Movies.iloc[(i-1),5]=Rating.text+number.text

        plot= driver.find_element(By.XPATH, f"/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{i}]/div/div/div/div[2]/div/div")
        Movies.iloc[(i-1),9]=plot.text
        # Drivers[i-1].quit()
# Out:
# /tmp/ipykernel_5926/222581040.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Frank Darabont' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),k]=Directors[:-2]
# /tmp/ipykernel_5926/222581040.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Tim Robbins, Morgan Freeman, Bob Gunton' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),k]=Directors[:-2]
# /tmp/ipykernel_5926/222581040.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1. The Shawshank Redemption' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),0]=title.text
# /tmp/ipykernel_5926/222581040.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'https://m.media-amazon.com/images/M/MV5BMDAyY2FhYjctNDc5OS00MDNlLThiMGUtY2UxYWVkNGY2ZjljXkEyXkFqcGc@._V1_QL75_UX140_CR0,1,140,207_.jpg' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),1]=image.get_attribute('src')
# /tmp/ipykernel_5926/222581040.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2h 22m' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),(j+1)]=elem.text
# /tmp/ipykernel_5926/222581040.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'R' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),(j+1)]=elem.text
# /tmp/ipykernel_5926/222581040.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '9.3 (3M)' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),5]=Rating.text+number.text
# /tmp/ipykernel_5926/222581040.py:41: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[(i-1),9]=plot.text

# %%
for i in range(4,-1,-1):
        drivers[i].get(link[i])

# %%
for i in range(4,-1,-1):
        # driver.get(links[i])
        for k in range (10,14):
                try:
                        Release_Date=drivers[i].find_element(By.XPATH,f"/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/section[{k}]/div[2]/ul/li[1]/div/ul/li/a")
                        Movies.iloc[i,2]=Release_Date.text

                        Countries=""
                        for j in range(1,10):
                                try:
                                        Country=drivers[i].find_element(By.XPATH,f"/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/section[{k}]/div[2]/ul/li[2]/div/ul/li[{j}]/a")
                                        Countries=Countries+Country.text+", "
                                except:
                                        Movies.iloc[i,6]=Countries[:-2]
                                        break
                except:
                        continue
        driver[i].quit()
# Out:
# /tmp/ipykernel_5926/676723196.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'October 14, 1994 (United States)' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[i,2]=Release_Date.text
# /tmp/ipykernel_5926/676723196.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'United States' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Movies.iloc[i,6]=Countries[:-2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 18
#      16         except:
#      17                 continue
# ---> 18 driver[i].quit()
#
# TypeError: 'WebDriver' object is not subscriptable

# %%
driver.quit()
Movies.to_json('movies.json',orient='records',indent=4)
